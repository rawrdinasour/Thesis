# %%
import pickle
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns

from nltk.corpus import stopwords
stopwords = stopwords.words('english')

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from IPython.display import Image as im
style.use('fivethirtyeight')

from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()

# %%
stopwords.append('inquirer')
stopwords.append('cookies')
stopwords.append('repo')
stopwords.append('exec')
stopwords.append('dutee')
stopwords.append('said')
stopwords.append('yolanda')

# %%
df = pd.read_excel('./Scraped/questionnaires.xlsx')

# %%
df.head()
# Out:
#                                   questionnaire name  \
# 0                        Burn's Depression Checklist
# 1               Patient Health Questionnaire (PHQ-9)
# 2                        Beck's Depression Inventory
# 3  Personal Inventory for Depression and SAD Self...
# 4  Center for Epidemiologic Studies Depression Scale
#
#                                              content
# 0  Feeling sad or down in the dumps\nFeeling unha...
# 1  Little interest or pleasure in doing things\nF...
# 2  I do not feel sad.\nI feel sad\nI am sad all t...
# 3  Were there two weeks or more . . .\nwhen you h...
# 4  I was bothered by things that usually don’t bo...

# %%
len(df)
# Out:
# 5

# %% [markdown]
# # Cleaning

# %%
def clean_text(df):
    df['cleaned_text'] = df['content'].fillna('')
    df['cleaned_text'] = df['cleaned_text'].str.lower()
    df['cleaned_text'] = df['cleaned_text'].str.replace(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|rt|\d+', ' ')
    df['cleaned_text'] = df['cleaned_text'].str.replace(r'^\s+|\s+$', '') 
    df['cleaned_text'] = df['cleaned_text'].apply(lambda x: ' '.join([w for w in x.split() if w not in (stopwords)]))
    df['cleaned_split'] = df['cleaned_text'].apply(lambda x: x.split())
    return df

# %%
def lemmatize_df(df):
    df['lemmatized'] = df['cleaned_split'].apply(lambda x : [lemmatizer.lemmatize(word) for word in x])
    return df

# %%
df = clean_text(df)
# df = lemmatize_df(df)

# %%
df.head()
# Out:
#                                   questionnaire name  \
# 0                        Burn's Depression Checklist
# 1               Patient Health Questionnaire (PHQ-9)
# 2                        Beck's Depression Inventory
# 3  Personal Inventory for Depression and SAD Self...
# 4  Center for Epidemiologic Studies Depression Scale
#
#                                              content  \
# 0  Feeling sad or down in the dumps\nFeeling unha...
# 1  Little interest or pleasure in doing things\nF...
# 2  I do not feel sad.\nI feel sad\nI am sad all t...
# 3  Were there two weeks or more . . .\nwhen you h...
# 4  I was bothered by things that usually don’t bo...
#
#                                         cleaned_text  \
# 0  feeling sad dumps feeling unhappy blue crying ...
# 1  little interest pleasure things feeling depres...
# 2  feel sad feel sad sad time snap sad unhappy st...
# 3  two weeks trouble falling asleep staying aslee...
# 4  bothered things usually bother feel like eatin...
#
#                                        cleaned_split
# 0  [feeling, sad, dumps, feeling, unhappy, blue, ...
# 1  [little, interest, pleasure, things, feeling, ...
# 2  [feel, sad, feel, sad, sad, time, snap, sad, u...
# 3  [two, weeks, trouble, falling, asleep, staying...
# 4  [bothered, things, usually, bother, feel, like...

# %%
len(df)
# Out:
# 5

# %% [markdown]
# # Analysis

# %%
def tweets_to_dtm(tweets):
    tweets = tweets['cleaned_text']
    vectorizer = CountVectorizer(max_features=2000)
    dtm = vectorizer.fit_transform(tweets)
    pickle.dump(vectorizer, open('out/dtm.pk', 'wb'))
    return dtm, vectorizer

def tweets_to_ngram(tweets, n=2):
    tweets = tweets['cleaned_text']
    vectorizer = CountVectorizer(
        ngram_range=(n, n),
        token_pattern=r'\b\w+\b',
        min_df=1,
        max_features=2000)
    dtm = vectorizer.fit_transform(tweets)
    pickle.dump(vectorizer, open('out/ngram.pk', 'wb'))
    return dtm, vectorizer

def tweets_to_tfidf(tweets):
    tweets = tweets['cleaned_text']
    vectorizer = TfidfVectorizer(max_features=2000)
    tfidf = vectorizer.fit_transform(tweets)
    pickle.dump(vectorizer, open('out/tfidf.pk', 'wb'))
    return tfidf, vectorizer

# %%
# Get TFIDF matrix
tfidf, tfidf_v = tweets_to_tfidf(df)
print('TFIDF matrix shape:', tfidf.toarray().shape)
list(tfidf_v.vocabulary_.items())[0:5]
# Out:
# TFIDF matrix shape: (5, 267)
# [('feeling', 92), ('sad', 196), ('dumps', 63), ('unhappy', 245), ('blue', 24)]

# %%
def vector_to_frequency(vector, vectorizer):
    """
    Return a list of words and their corresponding occurence in the corpus
    """
    total = vector.sum(axis=0)
    frequency = [(w, total[0, i]) for w, i in vectorizer.vocabulary_.items()]
    frequency = pd.DataFrame(frequency, columns=['term', 'frequency'])
    frequency = frequency.sort_values(by='frequency', ascending=False).reset_index(drop=True)
    return frequency

# %%
freq_tfidf = vector_to_frequency(tfidf, tfidf_v)
freq_tfidf.to_csv('out/frequency_tfidf.csv', index=False)
freq_tfidf.head(20)
# Out:
#         term  frequency
# 0    feeling   0.974465
# 1       felt   0.832848
# 2       tend   0.543037
# 3       feel   0.542129
# 4       loss   0.477000
# 5     little   0.423735
# 6       used   0.417849
# 7    trouble   0.413712
# 8   interest   0.411297
# 9     things   0.381294
# 10    moving   0.375055
# 11    people   0.354614
# 12    family   0.336716
# 13    energy   0.333567
# 14    change   0.316159
# 15     usual   0.300789
# 16  sleeping   0.297882
# 17     tired   0.292022
# 18  appetite   0.291085
# 19      life   0.286155

# %%
# Visualize frequencies
sns.barplot(data=freq_tfidf.head(20), x='frequency',
            y='term').set_title('Frequent terms in TFIDF')
# Out:
# Text(0.5, 1.0, 'Frequent terms in TFIDF')

# %%
df.head()
# Out:
#                                   questionnaire name  \
# 0                        Burn's Depression Checklist
# 1               Patient Health Questionnaire (PHQ-9)
# 2                        Beck's Depression Inventory
# 3  Personal Inventory for Depression and SAD Self...
# 4  Center for Epidemiologic Studies Depression Scale
#
#                                              content  \
# 0  Feeling sad or down in the dumps\nFeeling unha...
# 1  Little interest or pleasure in doing things\nF...
# 2  I do not feel sad.\nI feel sad\nI am sad all t...
# 3  Were there two weeks or more . . .\nwhen you h...
# 4  I was bothered by things that usually don’t bo...
#
#                                         cleaned_text  \
# 0  feeling sad dumps feeling unhappy blue crying ...
# 1  little interest pleasure things feeling depres...
# 2  feel sad feel sad sad time snap sad unhappy st...
# 3  two weeks trouble falling asleep staying aslee...
# 4  bothered things usually bother feel like eatin...
#
#                                        cleaned_split
# 0  [feeling, sad, dumps, feeling, unhappy, blue, ...
# 1  [little, interest, pleasure, things, feeling, ...
# 2  [feel, sad, feel, sad, sad, time, snap, sad, u...
# 3  [two, weeks, trouble, falling, asleep, staying...
# 4  [bothered, things, usually, bother, feel, like...

# %%
df.to_pickle('./Cleaned/questionnaire_cleaned.pkl')

# %%
"https://stackoverflow.com/questions/15424895/creating-lexicon-and-scanner-in-python"
# Out:
# 'https://stackoverflow.com/questions/15424895/creating-lexicon-and-scanner-in-python'

# %%
lexicon = list(freq_tfidf['term'])
lexicon
# Out:
# ['feeling',
#  'felt',
#  'tend',
#  'feel',
#  'loss',
#  'little',
#  'used',
#  'trouble',
#  'interest',
#  'things',
#  'moving',
#  'people',
#  'family',
#  'energy',
#  'change',
#  'usual',
#  'sleeping',
#  'tired',
#  'appetite',
#  'life',
#  'time',
#  'get',
#  'sleep',
#  'much',
#  'could',
#  'friends',
#  'would',
#  'lost',
#  'asleep',
#  'pleasure',
#  'thoughts',
#  'work',
#  'restless',
#  'depressed',
#  'poor',
#  'failure',
#  'lot',
#  'sad',
#  'activities',
#  'look',
#  'hopeless',
#  'like',
#  'difficulty',
#  'staying',
#  'falling',
#  'overeating',
#  'hu',
#  'concentrating',
#  'reading',
#  'ing',
#  'opposite',
#  'dead',
#  'newspaper',
#  'television',
#  'better',
#  'speaking',
#  'around',
#  'fidgety',
#  'slowly',
#  'watching',
#  'decisions',
#  'sex',
#  'crave',
#  'sweets',
#  'worried',
#  'bad',
#  'noticed',
#  'less',
#  'let',
#  'weight',
#  'worse',
#  'way',
#  'spells',
#  'crying',
#  'cry',
#  'anything',
#  'future',
#  'good',
#  'well',
#  'low',
#  'discouraged',
#  'making',
#  'satisfaction',
#  'everything',
#  'even',
#  'level',
#  'mood',
#  'overall',
#  'eat',
#  'found',
#  'morning',
#  'evening',
#  'afternoon',
#  'gain',
#  'starches',
#  'including',
#  'guilty',
#  'make',
#  'punished',
#  'irritated',
#  'unhappy',
#  'health',
#  'blue',
#  'dumps',
#  'tearfulness',
#  'harming',
#  'hless',
#  'motivation',
#  'guilt',
#  'inadequate',
#  'blaming',
#  'wo',
#  'esteem',
#  'self',
#  'others',
#  'colleagues',
#  'loneliness',
#  'spending',
#  'avoiding',
#  'criticizing',
#  'decreased',
#  'increased',
#  'worrying',
#  'extreme',
#  'plan',
#  'depression',
#  'suicidal',
#  'end',
#  'shame',
#  'effo',
#  'hours',
#  'keeping',
#  'help',
#  'fearful',
#  'blues',
#  'shake',
#  'mind',
#  'thought',
#  'eating',
#  'bother',
#  'usually',
#  'dislike',
#  'bothered',
#  'happy',
#  'talked',
#  'lonely',
#  'unfriendly',
#  'enjoyed',
#  'hopeful',
#  'going',
#  'physical',
#  'unattractive',
#  'pounds',
#  'anymore',
#  'hard',
#  'back',
#  'cannot',
#  'problems',
#  'pa',
#  'else',
#  'general',
#  'food',
#  'amount',
#  'slump',
#  'temporary',
#  'distinct',
#  'two',
#  'cravings',
#  'weeks',
#  'experienced',
#  'significant',
#  'late',
#  'although',
#  'dieting',
#  'daytime',
#  'workers',
#  'thinking',
#  'death',
#  'longer',
#  'length',
#  'nighttime',
#  'naps',
#  'waking',
#  'social',
#  'activity',
#  'included',
#  'co',
#  'total',
#  'letting',
#  'napping',
#  'mostly',
#  'summer',
#  'whether',
#  'earlier',
#  'blame',
#  'changes',
#  'permanent',
#  'person',
#  'old',
#  'looking',
#  'wake',
#  'kill',
#  'icularly',
#  'almost',
#  'disappointed',
#  'killing',
#  'ever',
#  'think',
#  'interested',
#  'quite',
#  'appearance',
#  'forward',
#  'stand',
#  'nothing',
#  'snap',
#  'bored',
#  'improve',
#  'failed',
#  'average',
#  'see',
#  'failures',
#  'complete',
#  'enjoy',
#  'real',
#  'dissatisfied',
#  'expect',
#  'may',
#  'disgusted',
#  'annoyed',
#  'hate',
#  'extra',
#  'find',
#  'chance',
#  'push',
#  'something',
#  'ed',
#  'sta',
#  'able',
#  'takes',
#  'anybody',
#  'ugly',
#  'believe',
#  'though',
#  'greater',
#  'put',
#  'want',
#  'slightly',
#  'several',
#  'easily',
#  'carry',
#  'lately',
#  'critical',
#  'mistakes',
#  'deal',
#  'faults',
#  'happens',
#  'completely',
#  'recent',
#  'constipation',
#  'stomach',
#  'upset',
#  'pains',
#  'aches',
#  'fifteen',
#  'ten',
#  'five',
#  'weaknesses']
