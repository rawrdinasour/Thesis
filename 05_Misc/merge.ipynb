# %%
import pandas as pd

# %%
df1 = pd.read_csv('./Scraped/inquirer-reports.csv')

# %%
df2 = pd.read_csv('./Scraped/rappler-reports.csv')

# %%
df3 = df1.append(df2, ignore_index=True)

# %%
df3.rename(columns={'narrative':'content'})
# Out:
#                                                    url  \
# 0    https://newsinfo.inquirer.net/1198980/icc-upda...
# 1    https://newsinfo.inquirer.net/1210965/46-slain...
# 2    https://newsinfo.inquirer.net/1276004/drug-war...
# 3    https://newsinfo.inquirer.net/1008295/killings...
# 4    https://newsinfo.inquirer.net/1043822/soccsksa...
# ..                                                 ...
# 366  https://www.google.com/url?client=internal-ele...
# 367  https://www.google.com/url?client=internal-ele...
# 368  https://www.google.com/url?client=internal-ele...
# 369  https://www.google.com/url?client=internal-ele...
# 370  https://www.google.com/url?client=internal-ele...
#
#                                                  title  \
# 0    ICC update gives ‘glimmer of hope’ for EJK vic...
# 1      46 slain in Soccsksargen’s war on drugs in 2019
# 2    Drug war killings rose in Central Visayas unde...
# 3        ‘Killings create climate of lawlessness’ – LP
# ...

# %%
df3.t
